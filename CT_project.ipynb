# %%
import numpy as np

# %%
import pandas as pd

df1 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv", encoding="ISO-8859-1", engine='python')
df2 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv", encoding="ISO-8859-1", engine='python')
df3 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv", encoding="ISO-8859-1", engine='python')
df4 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv", encoding="ISO-8859-1", engine='python')
df5 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv", encoding="ISO-8859-1", engine='python')
df6 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv", encoding="ISO-8859-1", engine='python')
df7 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv", encoding="ISO-8859-1", engine='python')
df8 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv", encoding="ISO-8859-1", engine='python')
df9 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv", encoding="ISO-8859-1", engine='python')
df10 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv", encoding="ISO-8859-1", engine='python')
df11 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv", encoding="ISO-8859-1", engine='python')
df12 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv", encoding="ISO-8859-1", engine='python')
df13 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv", encoding="ISO-8859-1", engine='python')
df14 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv", encoding="ISO-8859-1", engine='python')
df15 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv", encoding="ISO-8859-1", engine='python')
df16 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv", encoding="ISO-8859-1", engine='python')
df17 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv", encoding="ISO-8859-1", engine='python')
df18 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv", encoding="ISO-8859-1", engine='python')
df19 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv", encoding="ISO-8859-1", engine='python')
df20 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv", encoding="ISO-8859-1", engine='python')
df21 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv", encoding="ISO-8859-1", engine='python')
df22 = pd.read_csv("C:/Users/CHINNAMUTHU/Desktop/human_resource project/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv", encoding="ISO-8859-1", engine='python')

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22])
df.head()
# Out:
#   State Code District Code       India/States Division Group  Class  \
# 0        `08          `000  STATE - RAJASTHAN      `00  `000  `0000
# 1        `08          `000  STATE - RAJASTHAN      `01  `000  `0000
# 2        `08          `000  STATE - RAJASTHAN      `01  `011  `0000
# 3        `08          `000  STATE - RAJASTHAN      `01  `011  `0111
# 4        `08          `000  STATE - RAJASTHAN      `01  `011  `0112
#
#                                             NIC Name  \
# 0                                              Total
# 1  Crop and animal production, hunting and relate...
# 2                     Growing of non-perennial crops
# 3  Growing of cereals (except rice), leguminous c...
# 4                                    Growing of rice
#
#    Main Workers - Total -  Persons  Main Workers - Total - Males  \
# 0                          9017944                       7594737
# 1                           450766                        201572
# 2                            12876                         10547
# 3                            12061                          9911
# 4                               79                            71
#
#    Main Workers - Total - Females  ...  Main Workers - Urban - Females  \
# 0                         1423207  ...                          618445
# 1                          249194  ...                           19810
# 2                            2329  ...                            1013
# 3                            2150  ...                             942
# 4                               8  ...                               2
#
#    Marginal Workers - Total -  Persons  Marginal Workers - Total - Males  \
# 0                              2307752                           1046813
# 1                               408728                             76106
# 2                                 9562                              4051
# 3                                 9085                              3883
# 4                                   13                                 4
#
#    Marginal Workers - Total - Females  Marginal Workers - Rural -  Persons  \
# 0                             1260939                              1825830
# 1                              332622                               390864
# 2                                5511                                 8147
# 3                                5202                                 7777
# 4                                   9                                   11
#
#    Marginal Workers - Rural - Males  Marginal Workers - Rural - Females  \
# 0                            749381                             1076449
# 1                             71124                              319740
# 2                              3295                                4852
# 3                              3161                                4616
# 4                                 2                                   9
#
#    Marginal Workers - Urban -  Persons  Marginal Workers - Urban - Males  \
# 0                               481922                            297432
# 1                                17864                              4982
# 2                                 1415                               756
# 3                                 1308                               722
# 4                                    2                                 2
#
#    Marginal Workers - Urban - Females
# 0                              184490
# 1                               12882
# 2                                 659
# 3                                 586
# 4                                   0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (184948, 25)

# %%
df.to_csv("all_of_comined.csv",index =False)

# %%
# remove unnec comma, semi colon,
df['State Code'] = df['State Code'].astype(str).str.replace('`', '').astype(int)
df['District Code'] = df['District Code'].astype(str).str.replace('`', '').astype(int)
df['Division'] = df['Division'].astype(str).str.replace('`', '').astype(int)
df['Group'] = df['Group'].astype(str).str.replace('`', '').astype(int)
df['Class'] = df['Class'].astype(str).str.replace('`', '').astype(int)

# %%
df.columns
# Out:
# Index(['State Code', 'District Code', 'India/States', 'Division', 'Group',
#        'Class', 'NIC Name', 'Main Workers - Total -  Persons',
#        'Main Workers - Total - Males', 'Main Workers - Total - Females',
#        'Main Workers - Rural -  Persons', 'Main Workers - Rural - Males',
#        'Main Workers - Rural - Females', 'Main Workers - Urban -  Persons',
#        'Main Workers - Urban - Males', 'Main Workers - Urban - Females',
#        'Marginal Workers - Total -  Persons',
#        'Marginal Workers - Total - Males',
#        'Marginal Workers - Total - Females',
#        'Marginal Workers - Rural -  Persons',
#        'Marginal Workers - Rural - Males',
#        'Marginal Workers - Rural - Females',
#        'Marginal Workers - Urban -  Persons',
#        'Marginal Workers - Urban - Males',
#        'Marginal Workers - Urban - Females'],
#       dtype='object')

# %%
# remove spl char

def remove_sp_char(column_name):
    return ''.join(e for e in column_name if e.isalnum() or e in ('_', '.'))

df.columns = [remove_sp_char(col) for col in df.columns]

# %%
df.columns
# Out:
# Index(['StateCode', 'DistrictCode', 'IndiaStates', 'Division', 'Group',
#        'Class', 'NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# 0                7594737                  1423207  ...
# 1                 201572                   249194  ...
# 2                  10547                     2329  ...
#
#    MainWorkersUrbanFemales  MarginalWorkersTotalPersons  \
# 0                   618445                      2307752
# 1                    19810                       408728
# 2                     1013                         9562
#
#    MarginalWorkersTotalMales  MarginalWorkersTotalFemales  \
# 0                    1046813                      1260939
# 1                      76106                       332622
# 2                       4051                         5511
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                      1825830                     749381
# 1                       390864                      71124
# 2                         8147                       3295
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                      1076449                       481922
# 1                       319740                        17864
# 2                         4852                         1415
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales
# 0                     297432                       184490
# 1                       4982                        12882
# 2                        756                          659
#
# [3 rows x 25 columns]

# %% [markdown]
# EDA (Exploriation Data Analysis )

# %%
non_numeric_columns =df.select_dtypes(exclude=[float, int]).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Calculate correlation
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                              StateCode  DistrictCode  Division     Group  \
# StateCode                     1.000000      0.846040 -0.007727 -0.003602
# DistrictCode                  0.846040      1.000000 -0.002876 -0.006676
# Division                     -0.007727     -0.002876  1.000000  0.748190
# Group                        -0.003602     -0.006676  0.748190  1.000000
# Class                        -0.000651     -0.007019  0.441167  0.594177
# MainWorkersTotalPersons      -0.005799     -0.030428 -0.010515 -0.014866
# MainWorkersTotalMales        -0.006909     -0.030077 -0.010990 -0.014888
# MainWorkersTotalFemales      -0.000486     -0.029704 -0.007642 -0.013663
# MainWorkersRuralPersons      -0.006833     -0.030615 -0.014027 -0.016924
# MainWorkersRuralMales        -0.007791     -0.030176 -0.013318 -0.016221
# MainWorkersRuralFemales      -0.002506     -0.029365 -0.015406 -0.017996
# MainWorkersUrbanPersons      -0.004840     -0.029539 -0.007483 -0.012878
# MainWorkersUrbanMales        -0.006083     -0.029339 -0.008972 -0.013543
# MainWorkersUrbanFemales       0.001465     -0.028296  0.000195 -0.008742
# MarginalWorkersTotalPersons  -0.007290     -0.029587 -0.011558 -0.015037
# MarginalWorkersTotalMales    -0.005895     -0.029530 -0.011856 -0.015408
# MarginalWorkersTotalFemales  -0.008217     -0.028228 -0.010734 -0.013981
# MarginalWorkersRuralPersons  -0.009636     -0.030196 -0.015018 -0.016999
# MarginalWorkersRuralMales    -0.007878     -0.030063 -0.014369 -0.016825
# MarginalWorkersRuralFemales  -0.010528     -0.028779 -0.014770 -0.016278
# MarginalWorkersUrbanPersons  -0.001687     -0.025929 -0.003226 -0.009639
# MarginalWorkersUrbanMales    -0.002171     -0.027286 -0.006941 -0.012248
# MarginalWorkersUrbanFemales  -0.001027     -0.022989  0.001333 -0.006057
#
#                                 Class  MainWorkersTotalPersons  \
# StateCode                   -0.000651                -0.005799
# DistrictCode                -0.007019                -0.030428
# Division                     0.441167                -0.010515
# Group                        0.594177                -0.014866
# Class                        1.000000                -0.011472
# MainWorkersTotalPersons     -0.011472                 1.000000
# MainWorkersTotalMales       -0.011358                 0.996935
# MainWorkersTotalFemales     -0.011115                 0.938958
# MainWorkersRuralPersons     -0.012476                 0.982752
# MainWorkersRuralMales       -0.011992                 0.981072
# MainWorkersRuralFemales     -0.013137                 0.895109
# MainWorkersUrbanPersons     -0.010398                 0.989262
# MainWorkersUrbanMales       -0.010625                 0.987097
# MainWorkersUrbanFemales     -0.008543                 0.926005
# MarginalWorkersTotalPersons -0.011342                 0.931419
# MarginalWorkersTotalMales   -0.011615                 0.962668
# MarginalWorkersTotalFemales -0.010552                 0.858481
# MarginalWorkersRuralPersons -0.012273                 0.904806
# MarginalWorkersRuralMales   -0.012283                 0.942661
# MarginalWorkersRuralFemales -0.011647                 0.829550
# MarginalWorkersUrbanPersons -0.008445                 0.914339
# MarginalWorkersUrbanMales   -0.009933                 0.954723
# MarginalWorkersUrbanFemales -0.006251                 0.819444
#
#                              MainWorkersTotalMales  MainWorkersTotalFemales  \
# StateCode                                -0.006909                -0.000486
# DistrictCode                             -0.030077                -0.029704
# Division                                 -0.010990                -0.007642
# Group                                    -0.014888                -0.013663
# Class                                    -0.011358                -0.011115
# MainWorkersTotalPersons                   0.996935                 0.938958
# MainWorkersTotalMales                     1.000000                 0.909166
# MainWorkersTotalFemales                   0.909166                 1.000000
# MainWorkersRuralPersons                   0.978083                 0.930045
# MainWorkersRuralMales                     0.983619                 0.896761
# MainWorkersRuralFemales                   0.863222                 0.968630
# MainWorkersUrbanPersons                   0.987538                 0.923120
# MainWorkersUrbanMales                     0.990489                 0.898619
# MainWorkersUrbanFemales                   0.899942                 0.971609
# MarginalWorkersTotalPersons               0.917982                 0.921099
# MarginalWorkersTotalMales                 0.960677                 0.899688
# MarginalWorkersTotalFemales               0.835236                 0.896728
# MarginalWorkersRuralPersons               0.891679                 0.895105
# MarginalWorkersRuralMales                 0.941249                 0.878625
# MarginalWorkersRuralFemales               0.807901                 0.862934
# MarginalWorkersUrbanPersons               0.901306                 0.903515
# MarginalWorkersUrbanMales                 0.951810                 0.896390
# MarginalWorkersUrbanFemales               0.795116                 0.865362
#
#                              MainWorkersRuralPersons  MainWorkersRuralMales  \
# StateCode                                  -0.006833              -0.007791
# DistrictCode                               -0.030615              -0.030176
# Division                                   -0.014027              -0.013318
# Group                                      -0.016924              -0.016221
# Class                                      -0.012476              -0.011992
# MainWorkersTotalPersons                     0.982752               0.981072
# MainWorkersTotalMales                       0.978083               0.983619
# MainWorkersTotalFemales                     0.930045               0.896761
# MainWorkersRuralPersons                     1.000000               0.994983
# MainWorkersRuralMales                       0.994983               1.000000
# MainWorkersRuralFemales                     0.923500               0.880491
# MainWorkersUrbanPersons                     0.945170               0.946168
# MainWorkersUrbanMales                       0.943653               0.949462
# MainWorkersUrbanFemales                     0.882095               0.860009
# MarginalWorkersTotalPersons                 0.944651               0.928641
# MarginalWorkersTotalMales                   0.967585               0.968175
# MarginalWorkersTotalFemales                 0.878674               0.848273
# MarginalWorkersRuralPersons                 0.937504               0.919388
# MarginalWorkersRuralMales                   0.968215               0.968523
# MarginalWorkersRuralFemales                 0.866201               0.834554
# MarginalWorkersUrbanPersons                 0.884824               0.874599
# MarginalWorkersUrbanMales                   0.923397               0.924453
# MarginalWorkersUrbanFemales                 0.793592               0.770553
#
#                              ...  MainWorkersUrbanFemales  \
# StateCode                    ...                 0.001465
# DistrictCode                 ...                -0.028296
# Division                     ...                 0.000195
# Group                        ...                -0.008742
# Class                        ...                -0.008543
# MainWorkersTotalPersons      ...                 0.926005
# MainWorkersTotalMales        ...                 0.899942
# MainWorkersTotalFemales      ...                 0.971609
# MainWorkersRuralPersons      ...                 0.882095
# MainWorkersRuralMales        ...                 0.860009
# MainWorkersRuralFemales      ...                 0.882336
# MainWorkersUrbanPersons      ...                 0.938141
# MainWorkersUrbanMales        ...                 0.910611
# MainWorkersUrbanFemales      ...                 1.000000
# MarginalWorkersTotalPersons  ...                 0.872672
# MarginalWorkersTotalMales    ...                 0.872979
# MarginalWorkersTotalFemales  ...                 0.830782
# MarginalWorkersRuralPersons  ...                 0.821908
# MarginalWorkersRuralMales    ...                 0.831518
# MarginalWorkersRuralFemales  ...                 0.772971
# MarginalWorkersUrbanPersons  ...                 0.911995
# MarginalWorkersUrbanMales    ...                 0.906476
# MarginalWorkersUrbanFemales  ...                 0.871506
#
#                              MarginalWorkersTotalPersons  \
# StateCode                                      -0.007290
# DistrictCode                                   -0.029587
# Division                                       -0.011558
# Group                                          -0.015037
# Class                                          -0.011342
# MainWorkersTotalPersons                         0.931419
# MainWorkersTotalMales                           0.917982
# MainWorkersTotalFemales                         0.921099
# MainWorkersRuralPersons                         0.944651
# MainWorkersRuralMales                           0.928641
# MainWorkersRuralFemales                         0.915602
# MainWorkersUrbanPersons                         0.898262
# MainWorkersUrbanMales                           0.889637
# MainWorkersUrbanFemales                         0.872672
# MarginalWorkersTotalPersons                     1.000000
# MarginalWorkersTotalMales                       0.972667
# MarginalWorkersTotalFemales                     0.977273
# MarginalWorkersRuralPersons                     0.988357
# MarginalWorkersRuralMales                       0.967640
# MarginalWorkersRuralFemales                     0.954810
# MarginalWorkersUrbanPersons                     0.945400
# MarginalWorkersUrbanMales                       0.938128
# MarginalWorkersUrbanFemales                     0.905262
#
#                              MarginalWorkersTotalMales  \
# StateCode                                    -0.005895
# DistrictCode                                 -0.029530
# Division                                     -0.011856
# Group                                        -0.015408
# Class                                        -0.011615
# MainWorkersTotalPersons                       0.962668
# MainWorkersTotalMales                         0.960677
# MainWorkersTotalFemales                       0.899688
# MainWorkersRuralPersons                       0.967585
# MainWorkersRuralMales                         0.968175
# MainWorkersRuralFemales                       0.872689
# MainWorkersUrbanPersons                       0.935323
# MainWorkersUrbanMales                         0.933806
# MainWorkersUrbanFemales                       0.872979
# MarginalWorkersTotalPersons                   0.972667
# MarginalWorkersTotalMales                     1.000000
# MarginalWorkersTotalFemales                   0.901338
# MarginalWorkersRuralPersons                   0.950082
# MarginalWorkersRuralMales                     0.990765
# MarginalWorkersRuralFemales                   0.870328
# MarginalWorkersUrbanPersons                   0.943679
# MarginalWorkersUrbanMales                     0.971589
# MarginalWorkersUrbanFemales                   0.862022
#
#                              MarginalWorkersTotalFemales  \
# StateCode                                      -0.008217
# DistrictCode                                   -0.028228
# Division                                       -0.010734
# Group                                          -0.013981
# Class                                          -0.010552
# MainWorkersTotalPersons                         0.858481
# MainWorkersTotalMales                           0.835236
# MainWorkersTotalFemales                         0.896728
# MainWorkersRuralPersons                         0.878674
# MainWorkersRuralMales                           0.848273
# MainWorkersRuralFemales                         0.911123
# MainWorkersUrbanPersons                         0.821601
# MainWorkersUrbanMales                           0.806898
# MainWorkersUrbanFemales                         0.830782
# MarginalWorkersTotalPersons                     0.977273
# MarginalWorkersTotalMales                       0.901338
# MarginalWorkersTotalFemales                     1.000000
# MarginalWorkersRuralPersons                     0.976175
# MarginalWorkersRuralMales                       0.900392
# MarginalWorkersRuralFemales                     0.986410
# MarginalWorkersUrbanPersons                     0.901896
# MarginalWorkersUrbanMales                       0.862851
# MarginalWorkersUrbanFemales                     0.901575
#
#                              MarginalWorkersRuralPersons  \
# StateCode                                      -0.009636
# DistrictCode                                   -0.030196
# Division                                       -0.015018
# Group                                          -0.016999
# Class                                          -0.012273
# MainWorkersTotalPersons                         0.904806
# MainWorkersTotalMales                           0.891679
# MainWorkersTotalFemales                         0.895105
# MainWorkersRuralPersons                         0.937504
# MainWorkersRuralMales                           0.919388
# MainWorkersRuralFemales                         0.917215
# MainWorkersUrbanPersons                         0.856914
# MainWorkersUrbanMales                           0.850901
# MainWorkersUrbanFemales                         0.821908
# MarginalWorkersTotalPersons                     0.988357
# MarginalWorkersTotalMales                       0.950082
# MarginalWorkersTotalFemales                     0.976175
# MarginalWorkersRuralPersons                     1.000000
# MarginalWorkersRuralMales                       0.963868
# MarginalWorkersRuralFemales                     0.977952
# MarginalWorkersUrbanPersons                     0.884805
# MarginalWorkersUrbanMales                       0.883711
# MarginalWorkersUrbanFemales                     0.840484
#
#                              MarginalWorkersRuralMales  \
# StateCode                                    -0.007878
# DistrictCode                                 -0.030063
# Division                                     -0.014369
# Group                                        -0.016825
# Class                                        -0.012283
# MainWorkersTotalPersons                       0.942661
# MainWorkersTotalMales                         0.941249
# MainWorkersTotalFemales                       0.878625
# MainWorkersRuralPersons                       0.968215
# MainWorkersRuralMales                         0.968523
# MainWorkersRuralFemales                       0.874340
# MainWorkersUrbanPersons                       0.899492
# MainWorkersUrbanMales                         0.899710
# MainWorkersUrbanFemales                       0.831518
# MarginalWorkersTotalPersons                   0.967640
# MarginalWorkersTotalMales                     0.990765
# MarginalWorkersTotalFemales                   0.900392
# MarginalWorkersRuralPersons                   0.963868
# MarginalWorkersRuralMales                     1.000000
# MarginalWorkersRuralFemales                   0.886987
# MarginalWorkersUrbanPersons                   0.898755
# MarginalWorkersUrbanMales                     0.930526
# MarginalWorkersUrbanFemales                   0.814849
#
#                              MarginalWorkersRuralFemales  \
# StateCode                                      -0.010528
# DistrictCode                                   -0.028779
# Division                                       -0.014770
# Group                                          -0.016278
# Class                                          -0.011647
# MainWorkersTotalPersons                         0.829550
# MainWorkersTotalMales                           0.807901
# MainWorkersTotalFemales                         0.862934
# MainWorkersRuralPersons                         0.866201
# MainWorkersRuralMales                           0.834554
# MainWorkersRuralFemales                         0.904623
# MainWorkersUrbanPersons                         0.780367
# MainWorkersUrbanMales                           0.769773
# MainWorkersUrbanFemales                         0.772971
# MarginalWorkersTotalPersons                     0.954810
# MarginalWorkersTotalMales                       0.870328
# MarginalWorkersTotalFemales                     0.986410
# MarginalWorkersRuralPersons                     0.977952
# MarginalWorkersRuralMales                       0.886987
# MarginalWorkersRuralFemales                     1.000000
# MarginalWorkersUrbanPersons                     0.829297
# MarginalWorkersUrbanMales                       0.802493
# MarginalWorkersUrbanFemales                     0.818241
#
#                              MarginalWorkersUrbanPersons  \
# StateCode                                      -0.001687
# DistrictCode                                   -0.025929
# Division                                       -0.003226
# Group                                          -0.009639
# Class                                          -0.008445
# MainWorkersTotalPersons                         0.914339
# MainWorkersTotalMales                           0.901306
# MainWorkersTotalFemales                         0.903515
# MainWorkersRuralPersons                         0.884824
# MainWorkersRuralMales                           0.874599
# MainWorkersRuralFemales                         0.839321
# MainWorkersUrbanPersons                         0.915383
# MainWorkersUrbanMales                           0.901850
# MainWorkersUrbanFemales                         0.911995
# MarginalWorkersTotalPersons                     0.945400
# MarginalWorkersTotalMales                       0.943679
# MarginalWorkersTotalFemales                     0.901896
# MarginalWorkersRuralPersons                     0.884805
# MarginalWorkersRuralMales                       0.898755
# MarginalWorkersRuralFemales                     0.829297
# MarginalWorkersUrbanPersons                     1.000000
# MarginalWorkersUrbanMales                       0.980071
# MarginalWorkersUrbanFemales                     0.972015
#
#                              MarginalWorkersUrbanMales  \
# StateCode                                    -0.002171
# DistrictCode                                 -0.027286
# Division                                     -0.006941
# Group                                        -0.012248
# Class                                        -0.009933
# MainWorkersTotalPersons                       0.954723
# MainWorkersTotalMales                         0.951810
# MainWorkersTotalFemales                       0.896390
# MainWorkersRuralPersons                       0.923397
# MainWorkersRuralMales                         0.924453
# MainWorkersRuralFemales                       0.830945
# MainWorkersUrbanPersons                       0.956214
# MainWorkersUrbanMales                         0.951737
# MainWorkersUrbanFemales                       0.906476
# MarginalWorkersTotalPersons                   0.938128
# MarginalWorkersTotalMales                     0.971589
# MarginalWorkersTotalFemales                   0.862851
# MarginalWorkersRuralPersons                   0.883711
# MarginalWorkersRuralMales                     0.930526
# MarginalWorkersRuralFemales                   0.802493
# MarginalWorkersUrbanPersons                   0.980071
# MarginalWorkersUrbanMales                     1.000000
# MarginalWorkersUrbanFemales                   0.905977
#
#                              MarginalWorkersUrbanFemales
# StateCode                                      -0.001027
# DistrictCode                                   -0.022989
# Division                                        0.001333
# Group                                          -0.006057
# Class                                          -0.006251
# MainWorkersTotalPersons                         0.819444
# MainWorkersTotalMales                           0.795116
# MainWorkersTotalFemales                         0.865362
# MainWorkersRuralPersons                         0.793592
# MainWorkersRuralMales                           0.770553
# MainWorkersRuralFemales                         0.805957
# MainWorkersUrbanPersons                         0.819906
# MainWorkersUrbanMales                           0.796361
# MainWorkersUrbanFemales                         0.871506
# MarginalWorkersTotalPersons                     0.905262
# MarginalWorkersTotalMales                       0.862022
# MarginalWorkersTotalFemales                     0.901575
# MarginalWorkersRuralPersons                     0.840484
# MarginalWorkersRuralMales                       0.814849
# MarginalWorkersRuralFemales                     0.818241
# MarginalWorkersUrbanPersons                     0.972015
# MarginalWorkersUrbanMales                       0.905977
# MarginalWorkersUrbanFemales                     1.000000
#
# [23 rows x 23 columns]

# %%
df.shape
# Out:
# (184948, 25)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def correlation_matrix():
    numberic_df = df.select_dtypes(include=['float64','int64'])
    
    plt.figure(figsize=(12,10))
    sns.heatmap(numberic_df.corr(), annot=True,cmap='coolwarm', fmt='.2f')
    plt.title('correlation Matrix')
    plt.show()
    
correlation_matrix()

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# 0                7594737                  1423207  ...
# 1                 201572                   249194  ...
# 2                  10547                     2329  ...
# 3                   9911                     2150  ...
# 4                     71                        8  ...
#
#    MainWorkersUrbanFemales  MarginalWorkersTotalPersons  \
# 0                   618445                      2307752
# 1                    19810                       408728
# 2                     1013                         9562
# 3                      942                         9085
# 4                        2                           13
#
#    MarginalWorkersTotalMales  MarginalWorkersTotalFemales  \
# 0                    1046813                      1260939
# 1                      76106                       332622
# 2                       4051                         5511
# 3                       3883                         5202
# 4                          4                            9
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                      1825830                     749381
# 1                       390864                      71124
# 2                         8147                       3295
# 3                         7777                       3161
# 4                           11                          2
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                      1076449                       481922
# 1                       319740                        17864
# 2                         4852                         1415
# 3                         4616                         1308
# 4                            9                            2
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales
# 0                     297432                       184490
# 1                       4982                        12882
# 2                        756                          659
# 3                        722                          586
# 4                          2                            0
#
# [5 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# StateCode                      0
# DistrictCode                   0
# IndiaStates                    0
# Division                       0
# Group                          0
# Class                          0
# NICName                        0
# MainWorkersTotalPersons        0
# MainWorkersTotalMales          0
# MainWorkersTotalFemales        0
# MainWorkersRuralPersons        0
# MainWorkersRuralMales          0
# MainWorkersRuralFemales        0
# MainWorkersUrbanPersons        0
# MainWorkersUrbanMales          0
# MainWorkersUrbanFemales        0
# MarginalWorkersTotalPersons    0
# MarginalWorkersTotalMales      0
# MarginalWorkersTotalFemales    0
# MarginalWorkersRuralPersons    0
# MarginalWorkersRuralMales      0
# MarginalWorkersRuralFemales    0
# MarginalWorkersUrbanPersons    0
# MarginalWorkersUrbanMales      0
# MarginalWorkersUrbanFemales    0
# dtype: int64

# %%
df.describe().T
# Out:
#                                 count         mean           std  min    25%  \
# StateCode                    184948.0    19.739451      8.974234  2.0   12.0
# DistrictCode                 184948.0   341.485818    197.089775  0.0  203.0
# Division                     184948.0    46.503277     28.757178  0.0   23.0
# Group                        184948.0   389.890396    312.462230  0.0  103.0
# Class                        184948.0  2304.389899   3059.254839  0.0    0.0
# MainWorkersTotalPersons      184948.0  1571.350953  46922.490629  0.0    6.0
# MainWorkersTotalMales        184948.0  1256.589571  38764.336666  0.0    6.0
# MainWorkersTotalFemales      184948.0   314.761382   8815.049142  0.0    0.0
# MainWorkersRuralPersons      184948.0   694.843178  20999.448631  0.0    2.0
# MainWorkersRuralMales        184948.0   543.893635  16992.176923  0.0    1.0
# MainWorkersRuralFemales      184948.0   150.949543   4431.528572  0.0    0.0
# MainWorkersUrbanPersons      184948.0   876.507775  26570.575841  0.0    2.0
# MainWorkersUrbanMales        184948.0   712.695936  22262.242008  0.0    1.0
# MainWorkersUrbanFemales      184948.0   163.811839   4654.686895  0.0    0.0
# MarginalWorkersTotalPersons  184948.0   382.066657  12088.331059  0.0    0.0
# MarginalWorkersTotalMales    184948.0   191.300387   5916.448991  0.0    0.0
# MarginalWorkersTotalFemales  184948.0   190.766269   6480.886533  0.0    0.0
# MarginalWorkersRuralPersons  184948.0   262.075437   8455.030434  0.0    0.0
# MarginalWorkersRuralMales    184948.0   121.775764   3823.506178  0.0    0.0
# MarginalWorkersRuralFemales  184948.0   140.299673   4877.210993  0.0    0.0
# MarginalWorkersUrbanPersons  184948.0   119.991219   3947.262429  0.0    0.0
# MarginalWorkersUrbanMales    184948.0    69.524623   2190.486095  0.0    0.0
# MarginalWorkersUrbanFemales  184948.0    50.466596   1852.266490  0.0    0.0
#
#                                50%     75%         max
# StateCode                     20.0    27.0        34.0
# DistrictCode                 340.0   520.0       637.0
# Division                      46.0    69.0        99.0
# Group                        370.0   631.0       992.0
# Class                        124.5  4662.0      9920.0
# MainWorkersTotalPersons       32.0   208.0  15619759.0
# MainWorkersTotalMales         26.0   160.0  12801403.0
# MainWorkersTotalFemales        3.0    26.0   2818356.0
# MainWorkersRuralPersons       12.0    80.0   6770444.0
# MainWorkersRuralMales         10.0    62.0   5446541.0
# MainWorkersRuralFemales        0.0    10.0   1323903.0
# MainWorkersUrbanPersons       13.0    96.0   8849315.0
# MainWorkersUrbanMales         12.0    76.0   7354862.0
# MainWorkersUrbanFemales        1.0    12.0   1494453.0
# MarginalWorkersTotalPersons    5.0    30.0   3834122.0
# MarginalWorkersTotalMales      3.0    19.0   1966750.0
# MarginalWorkersTotalFemales    0.0     7.0   1867372.0
# MarginalWorkersRuralPersons    2.0    15.0   2515182.0
# MarginalWorkersRuralMales      0.0    10.0   1223824.0
# MarginalWorkersRuralFemales    0.0     3.0   1291358.0
# MarginalWorkersUrbanPersons    0.0    10.0   1318940.0
# MarginalWorkersUrbanMales      0.0     6.0    742926.0
# MarginalWorkersUrbanFemales    0.0     2.0    576014.0

# %%
df.nunique()
# Out:
# StateCode                        22
# DistrictCode                    401
# IndiaStates                     421
# Division                         89
# Group                           241
# Class                           423
# NICName                         587
# MainWorkersTotalPersons        8668
# MainWorkersTotalMales          7802
# MainWorkersTotalFemales        3963
# MainWorkersRuralPersons        5755
# MainWorkersRuralMales          5208
# MainWorkersRuralFemales        2688
# MainWorkersUrbanPersons        6559
# MainWorkersUrbanMales          5933
# MainWorkersUrbanFemales        2928
# MarginalWorkersTotalPersons    4188
# MarginalWorkersTotalMales      3163
# MarginalWorkersTotalFemales    2837
# MarginalWorkersRuralPersons    3384
# MarginalWorkersRuralMales      2517
# MarginalWorkersRuralFemales    2368
# MarginalWorkersUrbanPersons    2417
# MarginalWorkersUrbanMales      1947
# MarginalWorkersUrbanFemales    1553
# dtype: int64

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# 0                7594737                  1423207  ...
# 1                 201572                   249194  ...
# 2                  10547                     2329  ...
# 3                   9911                     2150  ...
# 4                     71                        8  ...
#
#    MainWorkersUrbanFemales  MarginalWorkersTotalPersons  \
# 0                   618445                      2307752
# 1                    19810                       408728
# 2                     1013                         9562
# 3                      942                         9085
# 4                        2                           13
#
#    MarginalWorkersTotalMales  MarginalWorkersTotalFemales  \
# 0                    1046813                      1260939
# 1                      76106                       332622
# 2                       4051                         5511
# 3                       3883                         5202
# 4                          4                            9
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                      1825830                     749381
# 1                       390864                      71124
# 2                         8147                       3295
# 3                         7777                       3161
# 4                           11                          2
#
#    MarginalWorkersRuralFemales  MarginalWorkersUrbanPersons  \
# 0                      1076449                       481922
# 1                       319740                        17864
# 2                         4852                         1415
# 3                         4616                         1308
# 4                            9                            2
#
#    MarginalWorkersUrbanMales  MarginalWorkersUrbanFemales
# 0                     297432                       184490
# 1                       4982                        12882
# 2                        756                          659
# 3                        722                          586
# 4                          2                            0
#
# [5 rows x 25 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt   
sns.histplot(x = 'IndiaStates', data = df, )
plt.show()

# %%
x_var = "MarginalWorkersTotalPersons"
y_var = "MainWorkersTotalPersons"
sns.boxplot(x = x_var, y = y_var, data = df)
plt.show()

# %%
y_var = "MainWorkersTotalPersons".strip()
sns.scatterplot(x = 'StateCode', y = y_var, data = df)
plt.xlabel('StateCode')
plt.ylabel('NumberofMainWorkers')
plt.title(' StateCode')
plt.show()

# %%
sns.boxplot( x = "NICName", y = 'MarginalWorkersTotalPersons', data = df)
plt.show()
# Out:
# C:\Users\CHINNAMUTHU\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Datas Cleaning  Procesures

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12042    False
# 12043    False
# 12044    False
# 12045    False
# 12046    False
# Length: 184948, dtype: bool

# %%
df.dtypes
# Out:
# StateCode                       int32
# DistrictCode                    int32
# IndiaStates                    object
# Division                        int32
# Group                           int32
# Class                           int32
# NICName                        object
# MainWorkersTotalPersons         int64
# MainWorkersTotalMales           int64
# MainWorkersTotalFemales         int64
# MainWorkersRuralPersons         int64
# MainWorkersRuralMales           int64
# MainWorkersRuralFemales         int64
# MainWorkersUrbanPersons         int64
# MainWorkersUrbanMales           int64
# MainWorkersUrbanFemales         int64
# MarginalWorkersTotalPersons     int64
# MarginalWorkersTotalMales       int64
# MarginalWorkersTotalFemales     int64
# MarginalWorkersRuralPersons     int64
# MarginalWorkersRuralMales       int64
# MarginalWorkersRuralFemales     int64
# MarginalWorkersUrbanPersons     int64
# MarginalWorkersUrbanMales       int64
# MarginalWorkersUrbanFemales     int64
# dtype: object

# %%
# Drop un nec cols
columns_to_drop = ["StateCode", "DistrictCode", "Division", "Group", "Class"]
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['IndiaStates', 'NICName', 'MainWorkersTotalPersons',
#        'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#        'MainWorkersRuralPersons', 'MainWorkersRuralMales',
#        'MainWorkersRuralFemales', 'MainWorkersUrbanPersons',
#        'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#        'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales',
#        'MarginalWorkersTotalFemales', 'MarginalWorkersRuralPersons',
#        'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
#        'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales',
#        'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
# Extract 'State' and 'District' from 'India/States' column
df[['State', 'District']] = df['IndiaStates'].str.extract(r'STATE - (\w+)|District - (\w+)', expand=True)
df = df.drop('IndiaStates', axis=1)

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       170868
# District     14080
# dtype: int64

# %%
# Fill NaN values in 'State' column with forward fill (ffill)
df['State'] = df['State'].ffill()
df['District'] = df['District'].bfill()

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       0
# District    0
# dtype: int64

# %% [markdown]
# Feature Engrr

# %%
# Example: Creating a new 'TotalWorkers' column by summing 'MainWorkersTotalPersons' and 'MarginalWorkersTotalPersons'
df['TotalWorkers'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['MaleFemaleRatio'] = df['MainWorkersTotalMales'] / (df['MainWorkersTotalFemales'].replace(0, 1))

# %%
df[['TotalWorkers', 'MaleFemaleRatio']].isnull().sum()
# Out:
# TotalWorkers       0
# MaleFemaleRatio    0
# dtype: int64

# %%
df['TotalPopulation'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['WorkersRatio'] = df['TotalWorkers'] / df['TotalPopulation']

# %%
df[['TotalPopulation', 'WorkersRatio']].isnull().sum()
# Out:
# TotalPopulation    0
# WorkersRatio       0
# dtype: int64

# %%
df[['TotalPopulation', 'WorkersRatio']] = df[['TotalPopulation', 'WorkersRatio']].astype(int)

# %%
# # download cleaned df
df.to_csv("HRM.csv", index = False)

# %%
# Replace 'file_path' with the path to your CSV file
file_path = r'C:/Users/CHINNAMUTHU/Desktop/human_resource project/all_of_comined.csv'

df_geo = pd.read_csv(file_path)

# %%
df_geo.nunique()
# Out:
# State Code                               22
# District Code                           401
# India/States                            421
# Division                                 89
# Group                                   241
# Class                                   423
# NIC Name                                587
# Main Workers - Total -  Persons        8668
# Main Workers - Total - Males           7802
# Main Workers - Total - Females         3963
# Main Workers - Rural -  Persons        5755
# Main Workers - Rural - Males           5208
# Main Workers - Rural - Females         2688
# Main Workers - Urban -  Persons        6559
# Main Workers - Urban - Males           5933
# Main Workers - Urban - Females         2928
# Marginal Workers - Total -  Persons    4188
# Marginal Workers - Total - Males       3163
# Marginal Workers - Total - Females     2837
# Marginal Workers - Rural -  Persons    3384
# Marginal Workers - Rural - Males       2517
# Marginal Workers - Rural - Females     2368
# Marginal Workers - Urban -  Persons    2417
# Marginal Workers - Urban - Males       1947
# Marginal Workers - Urban - Females     1553
# dtype: int64

# %%
# Drop the specified columns
df_geo = df_geo.drop(['Unnamed: 0', 'State.name'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Drop the specified columns
# ----> 2 df_geo = df_geo.drop(['Unnamed: 0', 'State.name'], axis=1)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4782, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4780 for axis, labels in axes.items():
#    4781     if labels is not None:
# -> 4782         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4784 if inplace:
#    4785     self._update_inplace(obj)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4824, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4822         new_axis = axis.drop(labels, level=level, errors=errors)
#    4823     else:
# -> 4824         new_axis = axis.drop(labels, errors=errors)
#    4825     indexer = axis.get_indexer(new_axis)
#    4827 # Case for non-unique axis
#    4828 else:
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7069, in Index.drop(self, labels, errors)
#    7067 if mask.any():
#    7068     if errors != "ignore":
# -> 7069         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7070     indexer = indexer[~mask]
#    7071 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0', 'State.name'] not found in axis"

# %%
# Concatenate the two DataFrames horizontally (along columns) based on their index
df_1 = pd.concat([df, df_geo[['latitude', 'longitude']]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Concatenate the two DataFrames horizontally (along columns) based on their index
# ----> 2 df_1 = pd.concat([df, df_geo[['latitude', 'longitude']]], axis=1)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6248, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6246 if nmissing:
#    6247     if nmissing == len(indexer):
# -> 6248         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6251     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['latitude', 'longitude'], dtype='object')] are in the [columns]"

# %%
df_1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_1.head()
#
# NameError: name 'df_1' is not defined

# %%
df_1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df_1.columns
#
# NameError: name 'df_1' is not defined

# %%
df_1[['latitude', 'longitude', ]].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df_1[['latitude', 'longitude', ]].isnull().sum()
#
# NameError: name 'df_1' is not defined

# %%
df_1.duplicated()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_1.duplicated()
#
# NameError: name 'df_1' is not defined

# %%
df_1.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_1.columns
#
# NameError: name 'df_1' is not defined

# %%
# Calculate the mean of the 'Latitude' and 'Longitude' columns
mean_latitude = df_1['latitude'].mean()
mean_longitude = df_1['longitude'].mean()

# Fill the missing values with their respective mean values
df_1.loc[:, 'latitude'] = df_1['latitude'].fillna(mean_latitude)
df_1.loc[:, 'longitude'] = df_1['longitude'].fillna(mean_longitude)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Calculate the mean of the 'Latitude' and 'Longitude' columns
# ----> 2 mean_latitude = df_1['latitude'].mean()
#       3 mean_longitude = df_1['longitude'].mean()
#       5 # Fill the missing values with their respective mean values
#
# NameError: name 'df_1' is not defined

# %%
df_1[['latitude', 'longitude']].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df_1[['latitude', 'longitude']].isnull().sum()
#
# NameError: name 'df_1' is not defined

# %% [markdown]
# Outlieres find

# %%
# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']

# Calculate outliers using Z-score
z_scores =df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Plot Box Plots to visualize the distribution and outliers
plt.figure(figsize=(12, 8))
df_1[numerical_columns].boxplot()
plt.title("Box Plot of Numerical Columns")
plt.xticks(rotation=90)
plt.show()

# Plot Box Plots separately for each numerical column to focus on individual distributions
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    df_1[[column]].boxplot()
    plt.title(f"Box Plot of {column}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 11
#       2 numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#       3                      'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#       4                      'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#    (...)
#       7                      'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
#       8                      'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']
#      10 # Calculate outliers using Z-score
# ---> 11 z_scores =df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())
#      13 # Set a threshold for Z-score (e.g., 3) to identify outliers
#      14 threshold = 3
#
# NameError: name 'df_1' is not defined

# %%
# Remove outliers

# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']

# Calculate Z-scores for each numerical column
z_scores = df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Remove rows with outliers in any numerical column
df_1_no_outliers = df_1[~outliers.any(axis=1)]

# Visualize the distribution of cleaned data with Box Plots
plt.figure(figsize=(12, 8))
df_1_no_outliers = df_1[~outliers.any(axis=1)]
df_1_no_outliers[numerical_columns].boxplot()  # Removed the square brackets here
plt.title("Box Plot of Numerical Columns (After Removing Outliers)")
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 13
#       4 numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#       5                      'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#       6                      'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#    (...)
#       9                      'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
#      10                      'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation', 'WorkersRatio']
#      12 # Calculate Z-scores for each numerical column
# ---> 13 z_scores = df_1[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())
#      15 # Set a threshold for Z-score (e.g., 3) to identify outliers
#      16 threshold = 3
#
# NameError: name 'df_1' is not defined

# %%
df_1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df_1.shape
#
# NameError: name 'df_1' is not defined

# %%
df_1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df_1.shape
#
# NameError: name 'df_1' is not defined

# %%
df_1['District']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df_1['District']
#
# NameError: name 'df_1' is not defined

# %%
df_1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df_1.info()
#
# NameError: name 'df_1' is not defined

# %%
df_1.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df_1.nunique()
#
# NameError: name 'df_1' is not defined

# %%
df_1.to_csv("newdf.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df_1.to_csv("newdf.csv", index = False)
#
# NameError: name 'df_1' is not defined

# %% [markdown]
# NLP

# %%
# new df_1
df_2 = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/newdf.csv")
df_2.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[90], line 2
#       1 # new df_1
# ----> 2 df_2 = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/newdf.csv")
#       3 df_2.head(2)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/project/Industrial-Human-Resource-Geo-Visualization/newdf.csv'

# %%
df_2.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df_2.columns.tolist()
#
# NameError: name 'df_2' is not defined

# %%
df_2['NICName'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df_2['NICName'].unique()
#
# NameError: name 'df_2' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
from nltk.probability import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CHINNAMUTHU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CHINNAMUTHU\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df_2.dtypes
#
# NameError: name 'df_2' is not defined

# %%
df_2['NICName'] = df_2['NICName'].astype(str)
def clean_and_tokenize(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Tokenization
    tokens = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    return tokens

# Apply the function to your textual data
df_2['NICName'] = df_2['NICName'].apply(clean_and_tokenize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df_2['NICName'] = df_2['NICName'].astype(str)
#       2 def clean_and_tokenize(text):
#       3     # Convert to lowercase
#       4     text = text.lower()
#
# NameError: name 'df_2' is not defined

# %%
from gensim.models import Word2Vec

# Assuming 'cleaned_tokens' is the column containing tokenized text
sentences = df_2['NICName'].tolist()

# Train Word2Vec model
model = Word2Vec(df_2['NICName'], vector_size=100, window=5, min_count=1, workers=4)

# Save the Word2Vec model
model.save("word2vec_model")

# You can use the trained Word2Vec model to get word vectors
word_to_check = 'uranium'
word_vector = model.wv[word_to_check]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from gensim.models import Word2Vec
#       3 # Assuming 'cleaned_tokens' is the column containing tokenized text
#       4 sentences = df_2['NICName'].tolist()
#
# ModuleNotFoundError: No module named 'gensim'

# %%
word_vector
# Out:
# array([-0.01508034,  0.02126257, -0.07640553, -0.00454259, -0.0101925 ,
#        -0.1176403 , -0.0535076 ,  0.12025674, -0.10516194,  0.04015394,
#         0.01182788, -0.00419687, -0.01286713,  0.09657102, -0.02165205,
#        -0.07586082,  0.0446655 , -0.05938649, -0.03908968, -0.06583445,
#         0.0500937 , -0.04036668, -0.01411055, -0.03681699,  0.01369553,
#         0.02249131, -0.02123968, -0.07224181, -0.01349332,  0.11002287,
#         0.02344254,  0.04180367, -0.06862141, -0.10044979, -0.01645979,
#         0.02591317, -0.02765744, -0.02826247,  0.06199779, -0.12531283,
#        -0.01866951, -0.06795172, -0.0181419 , -0.01327198, -0.00468047,
#         0.01157853, -0.05372981,  0.04720199,  0.04730352,  0.04778801,
#         0.01882384, -0.05030555,  0.00791607, -0.03973348,  0.02393773,
#         0.01066613,  0.01535521,  0.04516225, -0.01044879,  0.07064072,
#         0.07495586, -0.02886751,  0.00266692, -0.13314967, -0.05616973,
#         0.02091427,  0.06915985,  0.00666011, -0.07041915,  0.01942748,
#        -0.00163691, -0.02636125, -0.03825154, -0.00543728,  0.04090906,
#         0.02395544,  0.01240939, -0.04079596, -0.06135343,  0.06537569,
#        -0.01926776, -0.02800036, -0.05662626, -0.00375063,  0.01041262,
#         0.04006863, -0.01067228,  0.06185937,  0.01109369, -0.03935997,
#         0.1176457 ,  0.05726264,  0.02277246, -0.0288312 ,  0.05127374,
#         0.04359513,  0.07216134, -0.08492678,  0.01518006, -0.02438194],
#       dtype=float32)

# %%
print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(model)
#
# NameError: name 'model' is not defined

# %%
# Calculate word frequencies
all_tokens = [token for tokens_list in df_2['NICName'] for token in tokens_list]
freq_dist = FreqDist(all_tokens)

# Visualize word frequencies using a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dist)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 # Calculate word frequencies
# ----> 2 all_tokens = [token for tokens_list in df_2['NICName'] for token in tokens_list]
#       3 freq_dist = FreqDist(all_tokens)
#       5 # Visualize word frequencies using a word cloud
#
# NameError: name 'df_2' is not defined

# %%
# Create a sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Convert the list to a string
df_2['NICName_str'] = df_2['NICName'].apply(lambda x: ' '.join(map(str, x)))

# Apply sentiment analysis to the new string column
df_2['sentiment_score'] = df_2['NICName_str'].apply(lambda x: sia.polarity_scores(x)['compound'])
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Create a sentiment analyzer
# ----> 2 sia = SentimentIntensityAnalyzer()
#       4 # Convert the list to a string
#       5 df_2['NICName_str'] = df_2['NICName'].apply(lambda x: ' '.join(map(str, x)))
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\sentiment\vader.py:340, in SentimentIntensityAnalyzer.__init__(self, lexicon_file)
#     336 def __init__(
#     337     self,
#     338     lexicon_file="sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt",
#     339 ):
# --> 340     self.lexicon_file = nltk.data.load(lexicon_file)
#     341     self.lexicon = self.make_lex_dict()
#     342     self.constants = VaderConstants()
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource vader_lexicon not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('vader_lexicon')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt
#
#   Searched in:
#     - 'C:\\Users\\CHINNAMUTHU/nltk_data'
#     - 'c:\\Users\\CHINNAMUTHU\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'c:\\Users\\CHINNAMUTHU\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'c:\\Users\\CHINNAMUTHU\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\CHINNAMUTHU\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
# Assuming you have already trained and saved the Word2Vec model
# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'workers' is in the vocabulary
word_to_check = 'grapes' 

word_vector = loaded_model.wv[word_to_check]

# # Get the vocabulary of the model
# vocabulary = loaded_model.wv.key_to_index

# # Print the vocabulary
# print("Vocabulary:", vocabulary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 # Assuming you have already trained and saved the Word2Vec model
#       2 # Load the Word2Vec model
# ----> 3 loaded_model = Word2Vec.load("word2vec_model")
#       5 # Check if 'workers' is in the vocabulary
#       6 word_to_check = 'grapes'
#
# NameError: name 'Word2Vec' is not defined

# %%
# Get the vocabulary of the Word2Vec model
vocabulary = loaded_model.wv.key_to_index

# Print the first 10 words in the vocabulary
print(list(vocabulary.keys())[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Get the vocabulary of the Word2Vec model
# ----> 2 vocabulary = loaded_model.wv.key_to_index
#       4 # Print the first 10 words in the vocabulary
#       5 print(list(vocabulary.keys())[:10])
#
# NameError: name 'loaded_model' is not defined

# %%
# Check model


from gensim.models import Word2Vec

# Load the Word2Vec model
loaded_model = Word2Vec.load("word2vec_model")

# Check if 'MarginalWorkersRuralMales' is in the vocabulary
word_to_check = 'MarginalWorkersRuralMales'

if word_to_check in loaded_model.wv:
    print(f"The word '{word_to_check}' is present in the Word2Vec model's vocabulary.")
    # Retrieve the word vector if needed
    word_vector = loaded_model.wv[word_to_check]
    print("Word Vector:", word_vector)
else:
    print(f"The word '{word_to_check}' is not present in the Word2Vec model's vocabulary.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 4
#       1 # Check model
# ----> 4 from gensim.models import Word2Vec
#       6 # Load the Word2Vec model
#       7 loaded_model = Word2Vec.load("word2vec_model")
#
# ModuleNotFoundError: No module named 'gensim'

# %%
df.2.to_csv("final_HR.csv",index = False)
# Out:
#   Cell In[64], line 1
#     df.2.to_csv("final_HR.csv",index = False)
#       ^
# SyntaxError: invalid syntax

# %%
# Get the vocabulary of the Word2Vec model
vocabulary = loaded_model.wv.key_to_index

# Print the first 10 words in the vocabulary
print(list(vocabulary.keys())[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Get the vocabulary of the Word2Vec model
# ----> 2 vocabulary = loaded_model.wv.key_to_index
#       4 # Print the first 10 words in the vocabulary
#       5 print(list(vocabulary.keys())[:10])
#
# NameError: name 'loaded_model' is not defined

# %%
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'TotalPopulation',
#        'WorkersRatio', 'latitude', 'longitude', 'NICName_str',
#        'sentiment_score'],
#       dtype='object')

# %%
df2.to_csv("final_HR.csv", index = False)

# %%
model = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/all_of_comined.csv")
model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 model = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/all_of_comined.csv")
#       2 model
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/project/Industrial-Human-Resource-Geo-Visualization/all_of_comined.csv'

# %%
model['India/States'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 model['India/States'].unique()
#
# NameError: name 'model' is not defined

# %%
# State wise Districts datas 

states_data = {
    'Rajasthan': ['Jalor', 'Sirohi', 'Banswara', 'Ganganagar', 'Ajmer', 'Pali', 'Bikaner', 'Tonk', 'Sikar', 'Kota', 'Jhunjhunun', 'Dhaulpur', 'Rajsamand', 'Bhilwara', 'Alwar', 'Chittaurgarh', 'Bundi', 'Hanumangarh', 'Nagaur', 'Udaipur', 'Jhalawar', 'SawaiMadhopur', 'Baran', 'Jaipur', 'Bharatpur', 'Barmer', 'Karauli', 'Churu', 'Dausa', 'Jaisalmer', 'Dungarpur', 'Jodhpur'],
    'Odisha': ['Rayagada', 'Jajapur', 'Anugul', 'Sambalpur', 'Dhenkanal', 'Kalahandi', 'Nuapada', 'Khordha', 'Debagarh', 'Sundargarh', 'Koraput', 'Kandhamal', 'Kendujhar', 'Mayurbhanj', 'Kendrapara', 'Malkangiri', 'Jagatsinghapur', 'Puri', 'Cuttack', 'Bargarh', 'Bhadrak', 'Nayagarh', 'Gajapati', 'Baudh', 'Jharsuguda', 'Ganjam', 'Baleshwar', 'Nabarangapur', 'Balangir', 'Subarnapur'],
    'Assam': ['Chirang', 'Nalbari', 'Nagaon', 'Sonitpur', 'Goalpara', 'Udalguri', 'Darrang', 'Kamrup', 'Dhubri', 'Dhemaji', 'DimaHasao', 'Baksa', 'KarbiAnglong', 'Sivasagar', 'Kokrajhar', 'Tinsukia', 'Golaghat', 'Cachar', 'Dibrugarh', 'KamrupMetropolitan', 'Lakhimpur', 'Karimganj', 'Hailakandi', 'Barpeta', 'Morigaon', 'Jorhat', 'Bongaigaon'],
    'Nagaland': ['Chirang', 'Nalbari', 'Nagaon', 'Sonitpur', 'Goalpara', 'Udalguri', 'Darrang', 'Kamrup', 'Dhubri', 'Dhemaji', 'DimaHasao', 'Baksa', 'KarbiAnglong', 'Sivasagar', 'Kokrajhar', 'Tinsukia', 'Golaghat', 'Cachar', 'Dibrugarh', 'KamrupMetropolitan', 'Lakhimpur', 'Karimganj', 'Hailakandi', 'Barpeta', 'Morigaon', 'Jorhat', 'Bongaigaon'],
    'Sikkim': ['SouthDistrict', 'EastDistrict', 'NorthDistrict', 'WestDistrict'],
    'Bihar': ['Gaya', 'Nalanda', 'Patna', 'Araria', 'Supaul', 'Saran', 'Madhubani', 'Katihar', 'Kishanganj', 'Gopalganj', 'Darbhanga', 'Bhagalpur', 'Bhojpur', 'Buxar', 'Nawada', 'Muzaffarpur', 'Samastipur', 'Sheohar', 'Purnia', 'Munger', 'Sitamarhi', 'Begusarai', 'Rohtas', 'Jamui', 'Banka', 'Saharsa', 'Madhepura', 'Arwal', 'PurbaChamparan', 'Jehanabad', 'Sheikhpura', 'Vaishali', 'Khagaria', 'Lakhisarai', 'PashchimChamparan', 'KaimurBhabua', 'Siwan'],
    'Uttar Pradesh': ['Baghpat', 'Mahoba', 'KanpurNagar', 'Jhansi', 'Sultanpur', 'Saharanpur', 'Faizabad', 'Balrampur', 'Budaun', 'Mau', 'Auraiya', 'Muzaffarnagar', 'Chandauli', 'Kushinagar', 'Lalitpur', 'Lucknow', 'Shrawasti', 'Kaushambi', 'Allahabad', 'Ballia', 'AmbedkarNagar', 'Mathura', 'Aligarh', 'SantRavidasNagarBhadohi', 'RaeBareli', 'Sonbhadra', 'Ghaziabad', 'Mainpuri', 'Pilibhit', 'Bijnor', 'Bahraich', 'Banda', 'Mirzapur', 'Meerut', 'Rampur', 'Chitrakoot', 'KanshiramNagar', 'Etawah', 'Kheri', 'Kannauj', 'Jaunpur', 'Unnao', 'GautamBuddhaNagar', 'Hardoi', 'Agra', 'Farrukhabad', 'BaraBanki', 'Siddharthnagar', 'JyotibaPhuleNagar', 'Moradabad', 'Mahrajganj', 'Sitapur', 'Fatehpur', 'Ghazipur', 'Azamgarh', 'Jalaun', 'Gonda', 'Firozabad', 'Varanasi', 'SantKabirNagar', 'MahamayaNagar', 'Bareilly', 'Shahjahanpur', 'Basti', 'Gorakhpur', 'KanpurDehat', 'Deoria', 'Bulandshahr', 'Etah'],
    'Uttarakhand': ['Nainital', 'Pithoragarh', 'Hardwar', 'Chamoli', 'Dehradun', 'Rudraprayag', 'TehriGarhwal', 'Almora', 'Bageshwar', 'UdhamSinghNagar', 'Garhwal', 'Uttarkashi', 'Champawat'],
    'Himachal Pradesh': ['Nainital', 'Pithoragarh', 'Hardwar', 'Chamoli', 'Dehradun', 'Rudraprayag', 'TehriGarhwal', 'Almora', 'Bageshwar', 'UdhamSinghNagar', 'Garhwal', 'Uttarkashi', 'Champawat'],
    'Puducherry': ['Nainital', 'Pithoragarh', 'Hardwar', 'Chamoli', 'Dehradun', 'Rudraprayag', 'TehriGarhwal', 'Almora', 'Bageshwar', 'UdhamSinghNagar', 'Garhwal', 'Uttarkashi', 'Champawat'],
    'Tamil Nadu': ['Thoothukkudi', 'Karur', 'Namakkal', 'Dharmapuri', 'Nagapattinam', 'Thiruvarur', 'Ariyalur', 'Kancheepuram', 'Perambalur', 'Madurai', 'Coimbatore', 'Chennai', 'Kanniyakumari', 'Theni', 'Virudhunagar', 'Cuddalore', 'Salem', 'Dindigul', 'Ramanathapuram', 'Sivaganga', 'Tirunelveli', 'Erode', 'Viluppuram', 'Pudukkottai', 'Thanjavur', 'Thiruvallur', 'Tiruvannamalai', 'Krishnagiri', 'Tiruppur', 'Vellore', 'Tiruchirappalli', 'TheNilgiris'],
    'Kerala': ['Palakkad', 'Kannur', 'Kozhikode', 'Idukki', 'Thiruvananthapuram', 'Kasaragod', 'Kollam', 'Alappuzha', 'Thrissur', 'Ernakulam', 'Malappuram', 'Kottayam', 'Wayanad', 'Pathanamthitta'],
    'Goa': ['NorthGoa', 'SouthGoa'],
    'Karnataka': ['Kolar', 'DakshinaKannada', 'Yadgir', 'Chamarajanagar', 'Bijapur', 'Mandya', 'Udupi', 'Haveri', 'Davanagere', 'Hassan', 'Bangalore', 'Ramanagara', 'Chitradurga', 'Mysore', 'Dharwad', 'Shimoga', 'Koppal', 'Gulbarga', 'Bidar', 'Gadag', 'Kodagu', 'BangaloreRural', 'UttaraKannada', 'Raichur', 'Bagalkot', 'Belgaum', 'Bellary', 'Chikkaballapura', 'Chikmagalur', 'Tumkur'],
    'Maharashtra': ['Jalna', 'Kolhapur', 'Sindhudurg', 'Raigarh', 'Nanded', 'Washim', 'Gondiya', 'Gadchiroli', 'Dhule', 'Bid', 'Sangli', 'Wardha', 'Pune', 'Nagpur', 'Akola', 'Satara', 'Osmanabad', 'Yavatmal', 'Aurangabad', 'Ratnagiri', 'Parbhani', 'Latur', 'Nandurbar', 'Nashik', 'Mumbai', 'Solapur', 'Jalgaon', 'Ahmadnagar', 'Thane', 'Buldana', 'Amravati', 'Bhandara', 'MumbaiSuburban', 'Hingoli', 'Chandrapur'],
    'Gujarat': ['Rajkot', 'Ahmadabad', 'Navsari', 'Kheda', 'Patan', 'Tapi', 'Narmada', 'Porbandar', 'Anand', 'Vadodara', 'Surendranagar', 'Jamnagar', 'Kachchh', 'BanasKantha', 'SabarKantha', 'Dohad', 'TheDangs', 'Gandhinagar', 'Bhavnagar', 'Valsad', 'Amreli', 'Surat', 'PanchMahals', 'Junagadh', 'Bharuch', 'Mahesana'],
    'Jharkhand': ['Giridih', 'Khunti', 'Deoghar', 'Hazaribagh', 'Ramgarh', 'Lohardaga', 'PashchimiSinghbhum', 'Garhwa', 'Godda', 'Chatra', 'PurbiSinghbhum', 'Jamtara', 'Palamu', 'Latehar', 'Dhanbad', 'Sahibganj', 'Bokaro', 'Kodarma', 'SaraikelaKharsawan', 'Dumka', 'Gumla', 'Simdega', 'Ranchi', 'Pakur'],
    'Tripura': ['Dhalai', 'WestTripura', 'NorthTripura', 'SouthTripura'],
    'NCT of Delhi': ['Central', 'East', 'NewDelhi', 'North', 'West', 'NorthEast', 'SouthWest', 'South', 'NorthWest'],
    'West Bengal': ['Jalpaiguri', 'Hugli', 'Nadia', 'Haora', 'PaschimMedinipur', 'Kolkata', 'UttarDinajpur', 'Bankura', 'Murshidabad', 'NorthTwentyFourParganas', 'KochBihar', 'SouthTwentyFourParganas', 'PurbaMedinipur', 'Maldah', 'Darjiling', 'Puruliya', 'Birbhum', 'DakshinDinajpur', 'Barddhaman'],
    'Mizoram': ['Saiha', 'Aizawl', 'Kolasib', 'Mamit', 'Lunglei', 'Champhai', 'Lawngtlai', 'Serchhip'],
    'Manipur': ['ImphalEast', 'Ukhrul', 'Bishnupur', 'Senapati', 'ImphalWest', 'Chandel', 'Tamenglong', 'Churachandpur', 'Thoubal'],
    'Arunachal Pradesh': ['UpperSubansiri', 'DibangValley', 'Tirap', 'Anjaw', 'PapumPare', 'LowerDibangValley', 'WestSiang', 'Tawang', 'WestKameng', 'LowerSubansiri', 'KurungKumey', 'EastKameng', 'EastSiang', 'Lohit', 'Changlang', 'UpperSiang']
}

# %%
import re
district_list  = ['District - Ganganagar',
       'District - Hanumangarh', 'District - Bikaner', 'District - Churu',
       'District - Jhunjhunun', 'District - Alwar',
       'District - Bharatpur', 'District - Dhaulpur',
       'District - Karauli', 'District - Sawai Madhopur',
       'District - Dausa', 'District - Jaipur', 'District - Sikar',
       'District - Nagaur', 'District - Jodhpur', 'District - Jaisalmer',
       'District - Barmer', 'District - Jalor', 'District - Sirohi',
       'District - Pali', 'District - Ajmer', 'District - Tonk',
       'District - Bundi', 'District - Bhilwara', 'District - Rajsamand',
       'District - Dungarpur', 'District - Banswara',
       'District - Chittaurgarh', 'District - Kota', 'District - Baran',
       'District - Jhalawar', 'District - Udaipur',
       'District - Pratapgarh']
unique_districts = list(set([re.sub(r'[^a-zA-Z0-9]', '', district.split(" - ")[1]) for district in district_list]))

# Print the result without quotes
print(', '.join(unique_districts))
# Out:
# Jaisalmer, Bharatpur, Chittaurgarh, Karauli, Sikar, Udaipur, Jhalawar, Pratapgarh, Ganganagar, Jhunjhunun, Dhaulpur, Hanumangarh, Bhilwara, Ajmer, Jodhpur, Tonk, Barmer, Alwar, Jalor, Dausa, Dungarpur, Kota, Nagaur, Banswara, Sirohi, Bundi, SawaiMadhopur, Rajsamand, Bikaner, Pali, Churu, Baran, Jaipur

# %%
df_2.to_csv("final_HR.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df_2.to_csv("final_HR.csv", index = False)
#
# NameError: name 'df_2' is not defined

# %%
new_st = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")
new_st.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 new_st = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")
#       2 new_st.head(2)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv'

# %%
new_st.columns.unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 new_st.columns.unique
#
# NameError: name 'new_st' is not defined

# %%
unique_states = df_2['State'].unique()
unique_states
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 unique_states = df_2['State'].unique()
#       2 unique_states
#
# NameError: name 'df_2' is not defined

# %% [markdown]
# St Page creation

# %%
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
# Read the CSV data
data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")

# Create a sidebar selectbox for selecting the state
unique_states = sorted(data['State'].unique())
selected_state = st.sidebar.selectbox("Select State", unique_states, key="state_selector")

# Filter districts based on the selected state
filtered_districts = sorted(data[data['State'] == selected_state]['District'].unique())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Read the CSV data
# ----> 2 data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")
#       4 # Create a sidebar selectbox for selecting the state
#       5 unique_states = sorted(data['State'].unique())
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv'

# %%
import streamlit as st
import pandas as pd

data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")

unique_states = sorted(data['State'].unique())
selected_state = st.sidebar.selectbox("Select State", unique_states, key="state_selector")

# Filter districts based on the selected state
filtered_districts = sorted(data[data['State'] == selected_state]['District'].unique())
selected_district = st.sidebar.selectbox("Select District", filtered_districts, key="district_selector")

filtered_nic_names = data[data['District'] == selected_district]['NICName'].unique()
filtered_nic_names = [nic.replace('[', '').replace(']', '').replace("'", "") for nic in filtered_nic_names]
filtered_nic_names = [nic.capitalize() for nic in filtered_nic_names]
filtered_nic_names = sorted(filtered_nic_names)

selected_nic_name = st.sidebar.selectbox("Select NIC Name", filtered_nic_names, key="nic_name_selector")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[79], line 4
#       1 import streamlit as st
#       2 import pandas as pd
# ----> 4 data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")
#       6 unique_states = sorted(data['State'].unique())
#       7 selected_state = st.sidebar.selectbox("Select State", unique_states, key="state_selector")
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\CHINNAMUTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv'

# %%
# Plotting data for Rural, Main, and Urban workers
rural_cols = ['MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales']
urban_cols = ['MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales']

rural_data = data[rural_cols].sum().values
main_data = data[['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales']].iloc[0].values
urban_data = data[urban_cols].sum().values

# Plotting Rural, Main, and Urban data
fig, ax = plt.subplots(figsize=(10, 6))
x_labels = ['Rural', 'Main', 'Urban']
ax.bar(x_labels, rural_data, color='#1f77b4', label='Rural')
ax.bar(x_labels, main_data, bottom=rural_data, color='#ff7f0e', label='Main')
ax.bar(x_labels, urban_data, bottom=rural_data + main_data, color='#2ca02c', label='Urban')
ax.set_title(f"{selected_state} - {selected_district} - Workers Distribution")
ax.legend()
st.pyplot(fig)

# %%
# Plotting data for Marginal workers (using pie chart)
marginal_cols_rural = ['MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales']
marginal_cols_urban = ['MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales']

marginal_data_rural = data[marginal_cols_rural].sum().values
marginal_data_urban = data[marginal_cols_urban].sum().values

fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(marginal_data_rural, labels=marginal_cols_rural, autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#ff7f0e', '#2ca02c'])
ax.set_title(f"{selected_state} - {selected_district} - Rural Marginal Workers Distribution")
st.pyplot(fig)

fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(marginal_data_urban, labels=marginal_cols_urban, autopct='%1.1f%%', startangle=90, colors=['#1f77b4', '#ff7f0e', '#2ca02c'])
ax.set_title(f"{selected_state} - {selected_district} - Urban Marginal Workers Distribution")
st.pyplot(fig)

# %%
import folium
from folium.plugins import MarkerCluster

# %%
# if SELECT == "Geo - Maps":

data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")

map_data = data[['latitude', 'longitude']]

# Create a Folium map centered around India
india_map = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

# Add markers for each district
marker_cluster = MarkerCluster().add_to(india_map)
for index, row in map_data.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']]).add_to(marker_cluster)

# Display the map in Streamlit
folium_static(india_map)

# %%
data = pd.read_csv("D:/project/Industrial-Human-Resource-Geo-Visualization/final_HR.csv")

# import folium
# from folium.plugins import MarkerCluster
# import streamlit as st

# Get the data for the selected state and district
state_data = data[(data['State'] == selected_state)]
district_data = data[(data['District'] == selected_district)]


# Create a folium map centered at Delhi, India
folium_map = folium.Map(location=[28.6139, 77.2090], zoom_start=5)

# Create marker cluster for the points
marker_cluster = MarkerCluster().add_to(folium_map)

# Plot main workers for the selected state
for idx, row in state_data.iterrows():
    lat, lon = row['latitude'], row['longitude']
    total_workers = row['MainWorkersTotalPersons']
    male_female_ratio = row['MaleFemaleRatio']
    popup_text = f"State: {selected_state}<br>District: {selected_district}<br>Total Workers: {total_workers}<br>Male-Female Ratio: {male_female_ratio}"
    folium.Marker([lat, lon], popup=popup_text).add_to(marker_cluster)

# Plot main workers for the selected district
for idx, row in district_data.iterrows():
    lat, lon = row['latitude'], row['longitude']
    total_workers = row['MainWorkersTotalPersons']
    male_female_ratio = row['MaleFemaleRatio']
    popup_text = f"State: {selected_state}<br>District: {selected_district}<br>Total Workers: {total_workers}<br>Male-Female Ratio: {male_female_ratio}"
    folium.Marker([lat, lon], popup=popup_text).add_to(marker_cluster)

# Display the map using Streamlit
st.components.v1.html(folium_map._repr_html_(), width=700, height=500)

# %%
print(data.columns)

# %%
print(states_data)

# %%
# Define selected_state
unique_states = sorted(data['State'].unique())
selected_state = st.sidebar.selectbox("Select State", unique_states, key="state_selector")

# Filter districts based on the selected state
filtered_districts = sorted(data[data['State'] == selected_state]['District'].unique())
selected_district = st.sidebar.selectbox("Select District", filtered_districts, key="district_selector")

# Filter data based on user selections
state_data = data[(data['State'] == selected_state)]
district_data = data[(data['District'] == selected_district)]

# Display the filtered data for the selected state and district
st.write(f"Showing data for {selected_state} - {selected_district}")

# Total number of state workers
total_state_workers = state_data['MainWorkersTotalPersons'].sum()
st.write(f"Total number of state workers: {total_state_workers}")

# Total number of district workers
total_district_workers = district_data['MainWorkersTotalPersons'].sum()
st.write(f"Total number of district workers: {total_district_workers}")

# Data summary
st.subheader("Data Summary")
st.write(data.describe())

# %%
import plotly.express as px

# Filter data for Main, Rural, and Urban workers
main_cols = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales']
rural_cols = ['MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales']
urban_cols = ['MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales']

main_data = data.groupby('State')[main_cols].sum().reset_index()
rural_data = data.groupby('State')[rural_cols].sum().reset_index()
urban_data = data.groupby('State')[urban_cols].sum().reset_index()

# Plotting the differences in counts
fig = px.bar(main_data, x='State', y='MainWorkersTotalPersons', 
             title='Differences in Main, Rural, and Urban Workers Counts (State-wise)',
             labels={'MainWorkersTotalPersons': 'Total Workers Count'},
             color_discrete_sequence=['#1f77b4'], 
             template='plotly_white')

fig.add_bar(x=main_data['State'], y=main_data['MainWorkersTotalPersons'], 
            name='Main Workers', marker=dict(color='#1f77b4'))

fig.add_bar(x=rural_data['State'], y=rural_data['MainWorkersRuralPersons'], 
            name='Rural Workers', marker=dict(color='#ff7f0e'))

fig.add_bar(x=urban_data['State'], y=urban_data['MainWorkersUrbanPersons'], 
            name='Urban Workers', marker=dict(color='#2ca02c'))

# Update the layout for better visualization
fig.update_layout(barmode='stack', xaxis_title='State', yaxis_title='Total Workers Count', showlegend=True)

# Display the chart
st.plotly_chart(fig)

# %%
import plotly.express as px

# Filter data for Main, Rural, and Urban workers
main_cols = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales']
rural_cols = ['MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales']
urban_cols = ['MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales']

main_data = data.groupby('State')[main_cols].sum().reset_index()
rural_data = data.groupby('State')[rural_cols].sum().reset_index()
urban_data = data.groupby('State')[urban_cols].sum().reset_index()

# Plotting the differences in counts
fig = px.bar(main_data, x='State', y='MainWorkersTotalPersons', 
             title='Differences in Main, Rural, and Urban Workers Counts (State-wise)',
             labels={'MainWorkersTotalPersons': 'Total Workers Count'},
             color_discrete_sequence=['#1f77b4'], 
             template='plotly_white')

fig.add_bar(x=main_data['State'], y=main_data['MainWorkersTotalPersons'], 
            name='Main Workers', marker=dict(color='#1f77b4'))

fig.add_bar(x=rural_data['State'], y=rural_data['MainWorkersRuralPersons'], 
            name='Rural Workers', marker=dict(color='#ff7f0e'))

fig.add_bar(x=urban_data['State'], y=urban_data['MainWorkersUrbanPersons'], 
            name='Urban Workers', marker=dict(color='#2ca02c'))

# Update the layout for better visualization
fig.update_layout(barmode='stack', xaxis_title='State', yaxis_title='Total Workers Count (Log Scale)',
                  showlegend=True, yaxis_type="log")

# Display the chart
st.plotly_chart(fig)
